# %% [markdown]
# <a href="https://colab.research.google.com/github/czlee0223/FullMnist/blob/master/My_Personal_Mnist_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pre Setup for Fast functions

# %%
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Download MNIST Data

# %%
#hide
from fastbook import *
path = untar_data(URLs.MNIST)
#hide
Path.BASE_PATH = path
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='15687680' class='' max='15683414' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.03% [15687680/15683414 00:00&lt;00:00]
#     </div>

# %%
print(path.ls())
print((path/'training').ls())
print((path/'training/2').ls())
# Out:
# [Path('testing'), Path('training')]
# [Path('training/2'), Path('training/1'), Path('training/6'), Path('training/7'), Path('training/5'), Path('training/4'), Path('training/8'), Path('training/3'), Path('training/9'), Path('training/0')]
# ...

# %% [markdown]
# ### Print a sample to see the real image

# %%
from PIL import Image
from IPython.display import display

# Assuming path is already defined and points to your MNIST dataset
# (path/'training').ls() will give you a list of directories for each digit
# Let's choose the directory for digit '2' as an example
digit_2_path = path/'training'/'2'

# List the files within the digit '2' directory
image_files = digit_2_path.ls()

# Choose the first image file (assuming there's at least one)
if image_files:
    first_image_path = image_files[0]

    # Open the image using Pillow
    img = Image.open(first_image_path)

    # Display the image in the notebook output
    print(f"Displaying image from: {first_image_path}")
    display(img)
else:
    print("No image files found in the directory.")
# Out:
# Displaying image from: /root/.fastai/data/mnist_png/training/2/34606.png
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>

# %%
ones = (path/'training'/'1').ls().sorted()
twos = (path/'training'/'2').ls().sorted()
threes = (path/'training'/'3').ls().sorted()
fours = (path/'training'/'4').ls().sorted()
fives = (path/'training'/'5').ls().sorted()
sixes = (path/'training'/'6').ls().sorted()
sevens = (path/'training'/'7').ls().sorted()
eights = (path/'training'/'8').ls().sorted()
nines = (path/'training'/'9').ls().sorted()
len(ones)
# Out:
# 6742

# %%
one_tensors = [tensor(Image.open(o)) for o in ones]
two_tensors = [tensor(Image.open(o)) for o in twos]
three_tensors = [tensor(Image.open(o)) for o in threes]
four_tensors = [tensor(Image.open(o)) for o in fours]
five_tensors = [tensor(Image.open(o)) for o in fives]
six_tensors = [tensor(Image.open(o)) for o in sixes]
seven_tensors = [tensor(Image.open(o)) for o in sevens]
eight_tensors = [tensor(Image.open(o)) for o in eights]
nine_tensors = [tensor(Image.open(o)) for o in nines]

# %%
len(one_tensors),len(two_tensors),len(three_tensors),len(four_tensors),len(five_tensors),len(six_tensors),len(seven_tensors),len(eight_tensors),len(nine_tensors)
# Out:
# (6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949)

# %%
# prompt: stacked_threes = torch.stack(three_tensors).float()/255

stacked_ones = torch.stack(one_tensors).float()/255
stacked_twos = torch.stack(two_tensors).float()/255
stacked_threes = torch.stack(three_tensors).float()/255
stacked_fours = torch.stack(four_tensors).float()/255
stacked_fives = torch.stack(five_tensors).float()/255
stacked_sixes = torch.stack(six_tensors).float()/255
stacked_sevens = torch.stack(seven_tensors).float()/255
stacked_eights = torch.stack(eight_tensors).float()/255
stacked_nines = torch.stack(nine_tensors).float()/255
stacked_threes.shape, stacked_ones.shape, stacked_twos.shape, stacked_fours.shape, stacked_fives.shape, stacked_sixes.shape, stacked_sevens.shape, stacked_eights.shape, stacked_nines.shape
# Out:
# (torch.Size([6131, 28, 28]),
#  torch.Size([6742, 28, 28]),
#  torch.Size([5958, 28, 28]),
#  torch.Size([5842, 28, 28]),
#  torch.Size([5421, 28, 28]),
#  torch.Size([5918, 28, 28]),
#  torch.Size([6265, 28, 28]),
#  torch.Size([5851, 28, 28]),
#  torch.Size([5949, 28, 28]))

# %%
valid_ones = (path/'testing'/'1').ls().sorted()
valid_twos = (path/'testing'/'2').ls().sorted()
valid_threes = (path/'testing'/'3').ls().sorted()
valid_fours = (path/'testing'/'4').ls().sorted()
valid_fives = (path/'testing'/'5').ls().sorted()
valid_sixes = (path/'testing'/'6').ls().sorted()
valid_sevens = (path/'testing'/'7').ls().sorted()
valid_eights = (path/'testing'/'8').ls().sorted()
valid_nines = (path/'testing'/'9').ls().sorted()

valid_one_tensors = [tensor(Image.open(o)) for o in valid_ones]
valid_two_tensors = [tensor(Image.open(o)) for o in valid_twos]
valid_three_tensors = [tensor(Image.open(o)) for o in valid_threes]
valid_four_tensors = [tensor(Image.open(o)) for o in valid_fours]
valid_five_tensors = [tensor(Image.open(o)) for o in valid_fives]
valid_six_tensors = [tensor(Image.open(o)) for o in valid_sixes]
valid_seven_tensors = [tensor(Image.open(o)) for o in valid_sevens]
valid_eight_tensors = [tensor(Image.open(o)) for o in valid_eights]
valid_nine_tensors = [tensor(Image.open(o)) for o in valid_nines]

valid_stacked_ones = torch.stack(valid_one_tensors).float()/255
valid_stacked_twos = torch.stack(valid_two_tensors).float()/255
valid_stacked_threes = torch.stack(valid_three_tensors).float()/255
valid_stacked_fours = torch.stack(valid_four_tensors).float()/255
valid_stacked_fives = torch.stack(valid_five_tensors).float()/255
valid_stacked_sixes = torch.stack(valid_six_tensors).float()/255
valid_stacked_sevens = torch.stack(valid_seven_tensors).float()/255
valid_stacked_eights = torch.stack(valid_eight_tensors).float()/255
valid_stacked_nines = torch.stack(valid_nine_tensors).float()/255

# %% [markdown]
# For Ref:
#
# 1. Initialize the weights.
# 2. For each image, use these weights to predict whether it appears to be a 3 or a 7.
# 3. Based on these predictions, calculate how good the model is (its loss).
# 4. Calculate the gradient, which measures for each weight, how changing that weight would change the loss
# Step (that is, change) all the weights based on that calculation.
# 5. Go back to the step 2, and repeat the process.
# 6. Iterate until you decide to stop the training process (for instance, because the model is good enough or you don't want to wait any longer).
#
# for x,y in dl:
#
#     pred = model(x)
#     loss = loss_func(pred, y)
#     loss.backward()
#     parameters -= parameters.grad * lr

# %% [markdown]
# ## Definding the loss function

# %%
train_x = torch.cat([stacked_ones, stacked_twos, stacked_threes, stacked_fours, stacked_fives, stacked_sixes, stacked_sevens, stacked_eights, stacked_nines]).view(-1, 28*28)
train_y = tensor([1]*len(ones) + [2]*len(twos) + [3]*len(threes) + [4]*len(fours) + [5]*len(fives) + [6]*len(sixes) + [7]*len(sevens) + [8]*len(eights) + [9]*len(nines)).unsqueeze(1)
train_x.shape,train_y.shape
# Out:
# (torch.Size([54077, 784]), torch.Size([54077, 1]))

# %%
dset = list(zip(train_x,train_y))
x,y = dset[0]
x.shape,y.shape
# Out:
# (torch.Size([784]), torch.Size([1]))

# %%
valid_x = torch.cat([valid_stacked_ones, valid_stacked_twos, valid_stacked_threes, valid_stacked_fours, valid_stacked_fives, valid_stacked_sixes, valid_stacked_sevens, valid_stacked_eights, valid_stacked_nines]).view(-1, 28*28)
valid_y = tensor([1]*len(valid_ones) + [2]*len(valid_twos) + [3]*len(valid_threes) + [4]*len(valid_fours) + [5]*len(valid_fives) + [6]*len(valid_sixes) + [7]*len(valid_sevens) + [8]*len(valid_eights) + [9]*len(valid_nines)).unsqueeze(1)
valid_x.shape, valid_y.shape
# Out:
# (torch.Size([9020, 784]), torch.Size([9020, 1]))

# %%
dset = list(zip(train_x,train_y))
x,y = dset[0]
x.shape,y.shape
# Out:
# (torch.Size([784]), torch.Size([1]))

# %%
def init_params(size, std=1.0): return (torch.randn(size)*std).requires_grad_()
def linear1(xb, weights, bias): return xb@weights + bias

# %%
weights = init_params(28*28)
bias = init_params(1)
weights,bias
